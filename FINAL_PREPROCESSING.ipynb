# %%
# DATASETS LOAIDING

# %%
from docx import Document

# %%
import os

# %%
DATA_DIR = "datasets"

# %%
for files in os.listdir(DATA_DIR):
    doc_file_path = os.path.join(DATA_DIR, files)

    doc = Document(doc_file_path)

    print("File contents for : {}".format(doc_file_path))
    for paragraph in doc.paragraphs:
        print(paragraph.text)

# %%
# storing the data in the list 
content = []

for files in os.listdir(DATA_DIR):
    doc_file_path = os.path.join(DATA_DIR, files)

    doc = Document(doc_file_path)

    print("File contents for : {}".format(doc_file_path))
    for paragraph in doc.paragraphs:
        for word in paragraph.text.split():
            content.append(word)
# Out:
# File contents for : datasets\100999172-House-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\100999172-House-Rental-Agreement.pdf.docx
# File contents for : datasets\116950326-December-2012-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\116950326-December-2012-Rental-Agreement.pdf.docx
# File contents for : datasets\136441742-Rental-Agreement-Format.pdf - Copy.docx
# File contents for : datasets\136441742-Rental-Agreement-Format.pdf.docx
# File contents for : datasets\142106117-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\142106117-Rental-Agreement.pdf.docx
# File contents for : datasets\170499354-Anand-Nagar-Agreement.pdf - Copy.docx
# File contents for : datasets\170499354-Anand-Nagar-Agreement.pdf.docx
# File contents for : datasets\175488575-House-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\175488575-House-Rental-Agreement.pdf.docx
# File contents for : datasets\18325926-Rental-Agreement-1.pdf - Copy.docx
# File contents for : datasets\18325926-Rental-Agreement-1.pdf.docx
# File contents for : datasets\195231682-This-RENTAL-AGREEMENT-is-Made-and-Executed-on-24th-Day-of-September.pdf - Copy.docx
# File contents for : datasets\195231682-This-RENTAL-AGREEMENT-is-Made-and-Executed-on-24th-Day-of-September.pdf.docx
# File contents for : datasets\203615996-Rental-Agreement-Format.pdf - Copy.docx
# File contents for : datasets\203615996-Rental-Agreement-Format.pdf.docx
# File contents for : datasets\216973836-Rental-Agreement-Sample.pdf - Copy.docx
# File contents for : datasets\216973836-Rental-Agreement-Sample.pdf.docx
# File contents for : datasets\248636461-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\248636461-Rental-Agreement.pdf.docx
# File contents for : datasets\249104436-House-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\249104436-House-Rental-Agreement.pdf.docx
# File contents for : datasets\251798216-Rental-Agreement-Format1.pdf - Copy.docx
# File contents for : datasets\251798216-Rental-Agreement-Format1.pdf.docx
# File contents for : datasets\267005869-Rental-Tenant.pdf - Copy.docx
# File contents for : datasets\267005869-Rental-Tenant.pdf.docx
# File contents for : datasets\269135973-Udaya-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\269135973-Udaya-Rental-Agreement.pdf.docx
# File contents for : datasets\269137702-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\269137702-Rental-Agreement.pdf.docx
# File contents for : datasets\269760124-97646-41223-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\269760124-97646-41223-Rental-Agreement.pdf.docx
# File contents for : datasets\288024755-Rental-Agreement-1.pdf - Copy.docx
# File contents for : datasets\288024755-Rental-Agreement-1.pdf.docx
# File contents for : datasets\294331674-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\294331674-Rental-Agreement.pdf.docx
# File contents for : datasets\308044452-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\308044452-Rental-Agreement.pdf.docx
# File contents for : datasets\323828497-Rental-Agreement-Micky.pdf - Copy.docx
# File contents for : datasets\323828497-Rental-Agreement-Micky.pdf.docx
# File contents for : datasets\334060786-House-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\334060786-House-Rental-Agreement.pdf.docx
# File contents for : datasets\343492954-Rent-Agreement-3E.pdf - Copy.docx
# File contents for : datasets\343492954-Rent-Agreement-3E.pdf.docx
# File contents for : datasets\36199312-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\36199312-Rental-Agreement.pdf.docx
# File contents for : datasets\392810415-RENT-AGREEMENT.pdf - Copy.docx
# File contents for : datasets\392810415-RENT-AGREEMENT.pdf.docx
# File contents for : datasets\44737744-Maddireddy-Bhargava-Reddy-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\44737744-Maddireddy-Bhargava-Reddy-Rental-Agreement.pdf.docx
# File contents for : datasets\46239065-Standard-Rental-Agreement-Rental-With-Performance-Fee.pdf - Copy.docx
# File contents for : datasets\46239065-Standard-Rental-Agreement-Rental-With-Performance-Fee.pdf.docx
# File contents for : datasets\47854715-RENTAL-AGREEMENT.pdf - Copy.docx
# File contents for : datasets\47854715-RENTAL-AGREEMENT.pdf.docx
# File contents for : datasets\50070534-RENTAL-AGREEMENT (1).pdf - Copy.docx
# File contents for : datasets\50070534-RENTAL-AGREEMENT (1).pdf.docx
# File contents for : datasets\54770958-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\54770958-Rental-Agreement.pdf.docx
# File contents for : datasets\54945838-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\54945838-Rental-Agreement.pdf.docx
# File contents for : datasets\56736420-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\56736420-Rental-Agreement.pdf.docx
# File contents for : datasets\62126501-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\62126501-Rental-Agreement.pdf.docx
# File contents for : datasets\62144960-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\62144960-Rental-Agreement.pdf.docx
# File contents for : datasets\63057680-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\63057680-Rental-Agreement.pdf.docx
# File contents for : datasets\63793679-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\63793679-Rental-Agreement.pdf.docx
# File contents for : datasets\6683127-House-Rental-Contract-GERALDINE-GALINATO-v2-Page-1.pdf - Copy.docx
# File contents for : datasets\6683127-House-Rental-Contract-GERALDINE-GALINATO-v2-Page-1.pdf.docx
# File contents for : datasets\6683129-House-Rental-Contract-Geraldine-Galinato-v2.pdf - Copy.docx
# File contents for : datasets\6683129-House-Rental-Contract-Geraldine-Galinato-v2.pdf.docx
# File contents for : datasets\77112358-Jaggu-Rental-Agreemnt.pdf - Copy.docx
# File contents for : datasets\77112358-Jaggu-Rental-Agreemnt.pdf.docx
# File contents for : datasets\81655723-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\81655723-Rental-Agreement.pdf.docx
# File contents for : datasets\95421373-Agreement.pdf - Copy.docx
# File contents for : datasets\95421373-Agreement.pdf.docx
# File contents for : datasets\95980236-Rental-Agreement.pdf - Copy.docx
# File contents for : datasets\95980236-Rental-Agreement.pdf.docx
# File contents for : datasets\99699504-Rental-Agreement-English-Model.pdf - Copy.docx
# File contents for : datasets\99699504-Rental-Agreement-English-Model.pdf.docx

# %%
content
# Out:
# ['HOUSE',
#  'RENTAL',
#  'AGREEMENT',
#  'Rental',
#  'Agreement',
#  'made',
#  'on',
#  'Jan',
#  '10,',
#  '2011,',
#  'between',
#  'Namashivayam,',
#  'Plat',
#  'No-182,',
#  'Door',
#  'No',
#  '16',
#  'New/10',
#  'Old,',
#  '24th',
#  'East',
#  'Street,',
#  'Kamaraj',
#  'Nagar,',
#  'Thiruvanmiyur,',
#  'Chennai',
#  '(hereinafter',
#  'referred',
#  'to',
#  'as',
#  'landlord)',
#  'of',
#  'the',
#  'house',
#  'and',
#  'Mrs.Thenmalar,',
#  'W/O',
#  'Xavier,',
#  'Kottaikadu',
#  '(PO),',
#  'Vadakadu',
#  '(Via),',
#  'Pudukkottai',
#  '(Dt)',
#  '(hereinafter',
#  'referred',
#  'to',
#  'as',
#  'tenant)',
#  'of',
#  'the',
#  'First',
#  'floor',
#  'portion',
#  'of',
#  'the',
#  'building.',
#  'WHERE',
#  'IT',
#  'IS',
#  'AGREED',
#  'AND',
#  'DECLARED',
#  'AS',
#  'FOLLOWS:',
#  'The',
#  'Landlord',
#  'agrees',
#  'to',
#  'let',
#  'out',
#  'and',
#  'the',
#  'tenant',
#  'agrees',
#  'to',
#  'take',
#  'on',
#  'rent',
#  'the',
#  'First',
#  'floor',
#  'portion',
#  'of',
#  'the',
#  'building',
#  'Plat',
#  'No-182,',
#  'Door',
#  'No',
#  '16',
#  'New/10',
#  'Old,',
#  '24th',
#  'East',
#  'Street,',
#  'Kamaraj',
#  'Nagar,',
#  'Thiruvanmiyur',
#  'along',
#  'with',
#  'electrical',
#  'and',
#  'sanitary',
#  'fittings',
#  'and',
#  'other',
#  'accessories',
#  'fittings',
#  'and',
#  'structures',
#  '(hereinafter',
#  'called',
#  'the',
#  'premises)',
#  'from',
#  'Jan',
#  '10',
#  '2011',
#  'at',
#  'the',
#  'monthly',
#  'rent',
#  'of',
#  'Rs.',
#  '14500',
#  '(Fourteen',
#  'thousand',
#  'and',
#  'five',
#  'hundred',
#  'rupees)',
#  'being',
#  'payable',
#  'on',
#  'or',
#  'before',
#  '5th',
#  'of',
#  'every',
#  'month',
#  'to',
#  'the',
#  'Landlord.',
#  'The',
#  'period',
#  'of',
#  'this',
#  'agreement',
#  'shall',
#  'be',
#  'twelve',
#  'months',
#  'w.e.f',
#  'Jan',
#  '10,',
#  '2011.',
#  'The',
#  'tenant',
#  'has',
#  'paid',
#  'Rs.',
#  '100000(0ne',
#  'lack',
#  'Rupees)',
#  'as',
#  'advance',
#  'amount',
#  'for',
#  'the',
#  'above',
#  'building',
#  'and',
#  'the',
#  'landlord',
#  'shall',
#  'pay',
#  'this',
#  'said',
#  'advance',
#  'without',
#  'interest',
#  'to',
#  'the',
#  'tenant',
#  'at',
#  'the',
#  'time',
#  'of',
#  'vacating',
#  'the',
#  'premises',
#  'or',
#  'within',
#  '12',
#  'months',
#  'of',
#  'commencement',
#  'of',
#  'this',
#  'agreement',
#  'whichever',
#  'is',
#  'earlier.',
#  'At',
#  'the',
#  'termination',
#  'of',
#  'the',
#  'period',
#  'of',
#  'tenancy',
#  'the',
#  'tenant',
#  'agrees',
#  'to',
#  'surrender',
#  'to',
#  'the',
#  'Landlord',
#  'the',
#  'vacant',
#  'possession',
#  'of',
#  'the',
#  'premises',
#  'without',
#  'raising',
#  'any',
#  'objection.',
#  'This',
#  'rental',
#  'agreement',
#  'can',
#  'be',
#  'terminated',
#  'at',
#  'any',
#  'time',
#  'by',
#  'three',
#  'months',
#  'notice',
#  'on',
#  'either',
#  'side',
#  'and',
#  'on',
#  'such',
#  'termination',
#  'the',
#  'tenant',
#  'shall',
#  'surrender',
#  'the',
#  'vacant',
#  'possession',
#  'of',
#  'the',
#  'premises',
#  'to',
#  'the',
#  'Landlord.',
#  'If',
#  'for',
#  'by',
#  'any',
#  'reason',
#  'the',
#  'tenant',
#  'occupies',
#  'the',
#  'building',
#  'for',
#  'a',
#  'period',
#  'that',
#  'includes',
#  'part',
#  'of',
#  'a',
#  'month,',
#  'it',
#  'is',
#  'agreed',
#  'that',
#  'the',
#  'rent',
#  'will',
#  'be',
#  'charged',
#  'on',
#  'a',
#  'pro-rated',
#  'basis',
#  'for',
#  'that',
#  'month.',
#  'The',
#  'landlord',
#  'shall',
#  'pay',
#  'all',
#  'existing',
#  'and',
#  'future',
#  'taxes,',
#  'rates',
#  'and',
#  'assessments',
#  'in',
#  'respect',
#  'of',
#  'the',
#  'lease',
#  'hold',
#  'including',
#  'the',
#  'municipal',
#  'or',
#  'other',
#  'tax',
#  'assessed',
#  'by',
#  'a',
#  'local',
#  'authority',
#  'on',
#  'the',
#  'value',
#  'of',
#  'the',
#  'building',
#  'or',
#  'annual',
#  'letting',
#  'value',
#  'of',
#  'the',
#  'building',
#  'and',
#  'all',
#  'other',
#  'rates,',
#  'taxes',
#  'and',
#  'assessments',
#  'levied',
#  'by',
#  'any',
#  'authority',
#  'whatsoever.',
#  'The',
#  'tenant',
#  'shall',
#  'pay',
#  'the',
#  'electricity',
#  'and',
#  'water',
#  'supply',
#  'charges',
#  'for',
#  'the',
#  'period',
#  'of',
#  'time',
#  'he',
#  'occupies',
#  'the',
#  'premises.',
#  'The',
#  'tenant',
#  'agrees',
#  'to',
#  'leave',
#  'at',
#  'the',
#  'end',
#  'of',
#  'tenancy',
#  'the',
#  'premises',
#  'in',
#  'good',
#  'condition',
#  'as',
#  'they',
#  'are',
#  'now,',
#  'subject',
#  'to',
#  'reasonable',
#  'wear',
#  'and',
#  'tear.',
#  'The',
#  'tenant',
#  'also',
#  'agreed',
#  'not',
#  'to',
#  'let',
#  'out',
#  'the',
#  'building',
#  'or',
#  'a',
#  'portion',
#  'of',
#  'it',
#  'to',
#  'anybody',
#  'else.',
#  'The',
#  'tenant',
#  'shall',
#  'not',
#  'commit',
#  'any',
#  'act',
#  'of',
#  'waste',
#  'in',
#  'the',
#  'premises.',
#  '11',
#  'The',
#  'tenant',
#  'also',
#  'agrees',
#  'to',
#  'make',
#  'any',
#  'maintenance',
#  'on',
#  'the',
#  'building',
#  'as',
#  'mutually',
#  'agreed',
#  'upon',
#  'by',
#  'the',
#  'tenant',
#  'and',
#  'the',
#  'landlord',
#  'and',
#  'the',
#  'said',
#  'expenses',
#  'shall',
#  'be',
#  'adjusted',
#  'against',
#  'the',
#  'rent',
#  'amount',
#  'due',
#  'to',
#  'the',
#  'landlord.',
#  '12.The',
#  'landlord',
#  'shall',
#  'retain',
#  'the',
#  'original',
#  'of',
#  'this',
#  'agreement',
#  'and',
#  'the',
#  'tenant',
#  'shall',
#  'retain',
#  'its',
#  'duplicate.',
#  'WITNESS',
#  'WHERE',
#  'OF',
#  'Namashivayam',
#  ',',
#  'the',
#  'landlord',
#  'and',
#  'Mrs.Thenmalar,',
#  'the',
#  'tenant',
#  'have',
#  'affixed',
#  'their',
#  'signatures',
#  'on',
#  'Jan',
#  '10,',
#  '2011.',
#  '(Land',
#  'Lord)',
#  '(Tenant)',
#  'Witness:',
#  'HOUSE',
#  'RENTAL',
#  'AGREEMENT',
#  'Rental',
#  'Agreement',
#  'made',
#  'on',
#  'Jan',
#  '10,',
#  '2011,',
#  'between',
#  'Namashivayam,',
#  'Plat',
#  'No-182,',
#  'Door',
#  'No',
#  '16',
#  'New/10',
#  'Old,',
#  '24th',
#  'East',
#  'Street,',
#  'Kamaraj',
#  'Nagar,',
#  'Thiruvanmiyur,',
#  'Chennai',
#  '(hereinafter',
#  'referred',
#  'to',
#  'as',
#  'landlord)',
#  'of',
#  'the',
#  'house',
#  'and',
#  'Mrs.Thenmalar,',
#  'W/O',
#  'Xavier,',
#  'Kottaikadu',
#  '(PO),',
#  'Vadakadu',
#  '(Via),',
#  'Pudukkottai',
#  '(Dt)',
#  '(hereinafter',
#  'referred',
#  'to',
#  'as',
#  'tenant)',
#  'of',
#  'the',
#  'First',
#  'floor',
#  'portion',
#  'of',
#  'the',
#  'building.',
#  'WHERE',
#  'IT',
#  'IS',
#  'AGREED',
#  'AND',
#  'DECLARED',
#  'AS',
#  'FOLLOWS:',
#  'The',
#  'Landlord',
#  'agrees',
#  'to',
#  'let',
#  'out',
#  'and',
#  'the',
#  'tenant',
#  'agrees',
#  'to',
#  'take',
#  'on',
#  'rent',
#  'the',
#  'First',
#  'floor',
#  'portion',
#  'of',
#  'the',
#  'building',
#  'Plat',
#  'No-182,',
#  'Door',
#  'No',
#  '16',
#  'New/10',
#  'Old,',
#  '24th',
#  'East',
#  'Street,',
#  'Kamaraj',
#  'Nagar,',
#  'Thiruvanmiyur',
#  'along',
#  'with',
#  'electrical',
#  'and',
#  'sanitary',
#  'fittings',
#  'and',
#  'other',
#  'accessories',
#  'fittings',
#  'and',
#  'structures',
#  '(hereinafter',
#  'called',
#  'the',
#  'premises)',
#  'from',
#  'Jan',
#  '10',
#  '2011',
#  'at',
#  'the',
#  'monthly',
#  'rent',
#  'of',
#  'Rs.',
#  '14500',
#  '(Fourteen',
#  'thousand',
#  'and',
#  'five',
#  'hundred',
#  'rupees)',
#  'being',
#  'payable',
#  'on',
#  'or',
#  'before',
#  '5th',
#  'of',
#  'every',
#  'month',
#  'to',
#  'the',
#  'Landlord.',
#  'The',
#  'period',
#  'of',
#  'this',
#  'agreement',
#  'shall',
#  'be',
#  'twelve',
#  'months',
#  'w.e.f',
#  'Jan',
#  '10,',
#  '2011.',
#  'The',
#  'tenant',
#  'has',
#  'paid',
#  'Rs.',
#  '100000(0ne',
#  'lack',
#  'Rupees)',
#  'as',
#  'advance',
#  'amount',
#  'for',
#  'the',
#  'above',
#  'building',
#  'and',
#  'the',
#  'landlord',
#  'shall',
#  'pay',
#  'this',
#  'said',
#  'advance',
#  'without',
#  'interest',
#  'to',
#  'the',
#  'tenant',
#  'at',
#  'the',
#  'time',
#  'of',
#  'vacating',
#  'the',
#  'premises',
#  'or',
#  'within',
#  '12',
#  'months',
#  'of',
#  'commencement',
#  'of',
#  'this',
#  'agreement',
#  'whichever',
#  'is',
#  'earlier.',
#  'At',
#  'the',
#  'termination',
#  'of',
#  'the',
#  'period',
#  'of',
#  'tenancy',
#  'the',
#  'tenant',
#  'agrees',
#  'to',
#  'surrender',
#  'to',
#  'the',
#  'Landlord',
#  'the',
#  'vacant',
#  'possession',
#  'of',
#  'the',
#  'premises',
#  'without',
#  'raising',
#  'any',
#  'objection.',
#  'This',
#  'rental',
#  'agreement',
#  'can',
#  'be',
#  'terminated',
#  'at',
#  'any',
#  'time',
#  'by',
#  'three',
#  'months',
#  'notice',
#  'on',
#  'either',
#  'side',
#  'and',
#  'on',
#  'such',
#  'termination',
#  'the',
#  'tenant',
#  'shall',
#  'surrender',
#  'the',
#  'vacant',
#  'possession',
#  'of',
#  'the',
#  'premises',
#  'to',
#  'the',
#  'Landlord.',
#  'If',
#  'for',
#  'by',
#  'any',
#  'reason',
#  'the',
#  'tenant',
#  'occupies',
#  'the',
#  'building',
#  'for',
#  'a',
#  'period',
#  'that',
#  'includes',
#  'part',
#  'of',
#  'a',
#  'month,',
#  'it',
#  'is',
#  'agreed',
#  'that',
#  'the',
#  'rent',
#  'will',
#  'be',
#  'charged',
#  'on',
#  'a',
#  'pro-rated',
#  'basis',
#  'for',
#  'that',
#  'month.',
#  'The',
#  'landlord',
#  'shall',
#  'pay',
#  'all',
#  'existing',
#  'and',
#  'future',
#  'taxes,',
#  'rates',
#  'and',
#  'assessments',
#  'in',
#  'respect',
#  'of',
#  'the',
#  'lease',
#  'hold',
#  'including',
#  'the',
#  'municipal',
#  'or',
#  'other',
#  'tax',
#  'assessed',
#  'by',
#  'a',
#  'local',
#  'authority',
#  'on',
#  'the',
#  'value',
#  'of',
#  'the',
#  'building',
#  'or',
#  'annual',
#  'letting',
#  'value',
#  'of',
#  'the',
#  'building',
#  'and',
#  'all',
#  'other',
#  'rates,',
#  'taxes',
#  'and',
#  'assessments',
#  'levied',
#  'by',
#  'any',
#  'authority',
#  'whatsoever.',
#  'The',
#  'tenant',
#  'shall',
#  'pay',
#  'the',
#  'electricity',
#  'and',
#  'water',
#  'supply',
#  'charges',
#  'for',
#  'the',
#  'period',
#  'of',
#  'time',
#  'he',
#  'occupies',
#  'the',
#  'premises.',
#  'The',
#  'tenant',
#  'agrees',
#  'to',
#  'leave',
#  'at',
#  'the',
#  'end',
#  'of',
#  'tenancy',
#  'the',
#  'premises',
#  'in',
#  'good',
#  'condition',
#  'as',
#  'they',
#  'are',
#  'now,',
#  'subject',
#  'to',
#  'reasonable',
#  'wear',
#  'and',
#  'tear.',
#  'The',
#  'tenant',
#  'also',
#  'agreed',
#  'not',
#  'to',
#  'let',
#  'out',
#  'the',
#  'building',
#  'or',
#  'a',
#  'portion',
#  'of',
#  'it',
#  'to',
#  'anybody',
#  'else.',
#  'The',
#  'tenant',
#  'shall',
#  'not',
#  'commit',
#  'any',
#  'act',
#  'of',
#  'waste',
#  'in',
#  'the',
#  'premises.',
#  '11',
#  'The',
#  'tenant',
#  'also',
#  'agrees',
#  'to',
#  'make',
#  'any',
#  'maintenance',
#  'on',
#  'the',
#  'building',
#  'as',
#  'mutually',
#  'agreed',
#  'upon',
#  'by',
#  'the',
#  'tenant',
#  'and',
#  'the',
#  'landlord',
#  'and',
#  'the',
#  'said',
#  'expenses',
#  'shall',
#  'be',
#  'adjusted',
#  'against',
#  'the',
#  'rent',
#  'amount',
#  'due',
#  'to',
#  'the',
#  'landlord.',
#  '12.The',
#  'landlord',
#  'shall',
#  'retain',
#  'the',
#  'original',
#  'of',
#  'this',
#  'agreement',
#  'and',
#  'the',
#  'tenant',
#  'shall',
#  'retain',
#  'its',
#  'duplicate.',
#  'WITNESS',
#  'WHERE',
#  'OF',
#  'Namashivayam',
#  ',',
#  'the',
#  'landlord',
#  'and',
#  'Mrs.Thenmalar,',
#  'the',
#  'tenant',
#  'have',
#  'affixed',
#  'their',
#  'signatures',
#  'on',
#  'Jan',
#  '10,',
#  '2011.',
#  ...]

# %%
len(content)
# Out:
# 70520

# %% [markdown]
# PREPROCESSING
